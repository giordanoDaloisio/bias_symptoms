# %%
import pandas as pd

# %%
data = pd.read_csv('raw_data/nls/default.csv')

# %%
data.isna().any()[data.isna().any() == True]
# Out:
# Series([], dtype: bool)

# %%
print(pd.Series(data.columns))
# Out:
# 0           SCH_STATUS_1997.01
# 1           SCH_STATUS_1997.02
# 2           SCH_STATUS_1997.03
# 3           SCH_STATUS_1997.04
# 4           SCH_STATUS_1997.05
#                  ...
# 1501    TRAINING_CURFLAG.04.13
# 1502    TRAINING_CURFLAG.05.11
# 1503     TRAINING_CURFLAG.06.8
# 1504     TRAINING_CURFLAG.07.5
# 1505     TRAINING_CURFLAG.08.3
# Length: 1506, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8984 entries, 0 to 8983
# Columns: 1506 entries, SCH_STATUS_1997.01 to TRAINING_CURFLAG.08.3
# dtypes: int64(1506)
# memory usage: 103.2 MB

# %%
cols_2001 = [col for col in data.columns if '2001' in col]
data_2001 = data[cols_2001]

# %%
data_2001
# Out:
#       SCH_STATUS_2001.01  SCH_STATUS_2001.02  SCH_STATUS_2001.03  \
# 0                      1                   1                   1
# 1                      1                   1                   1
# 2                      2                   2                   2
# 3                      1                   1                   1
# 4                      1                   1                   1
# ...                  ...                 ...                 ...
# 8979                   1                   1                   1
# 8980                   2                   2                   2
# 8981                   1                   1                   1
# 8982                   1                   1                   1
# 8983                   1                   1                   1
#
#       SCH_STATUS_2001.04  SCH_STATUS_2001.05  SCH_STATUS_2001.06  \
# 0                      1                   1                   1
# ...
