# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", context="talk")

# %%
all = pd.read_csv('result_class/all_features.csv', index_col=[0,1])

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 6), sharey=True)
# data["statistical_parity"].value_counts(normalize=True).plot(kind='bar', ax=ax[0])
sns.barplot(data=all["statistical_parity"].value_counts(normalize=True), ax=ax[0])
ax[0].set_title("Statistical Parity")
ax[0].bar_label(ax[0].containers[0], fmt="%.2f")
ax[0].set_ylabel("")
sns.barplot(data=all["equal_opportunity"].value_counts(normalize=True), ax=ax[1])
ax[1].set_title("Equal Opportunity")
ax[1].bar_label(ax[1].containers[0], fmt="%.2f")
sns.barplot(data=all["average_odds"].value_counts(normalize=True), ax=ax[2])
ax[2].set_title("Average Odds")
ax[2].bar_label(ax[2].containers[0], fmt="%.2f")
plt.tight_layout()
plt.savefig('distribution.png', dpi=300)
plt.show()

# %%
ao = pd.read_csv('result_class/ao_all.csv', index_col=0)

# %%
sns.barplot(data=ao['average_odds'].value_counts(normalize=True))
# Out:
# <AxesSubplot:ylabel='average_odds'>
