# %%
import pandas as pd
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from joblib import load

sns.set_theme(style = 'whitegrid', context='talk')

# %% [markdown]
# # Selection of the best classifier

# %%
mlp = load('bias_symptoms_mlp.joblib')
rf = load('bias_symptoms_rf.joblib')
xgb = load('bias_symptoms_xgb.joblib')
# Out:
# c:\Users\giord\miniconda3\envs\bias\lib\site-packages\sklearn\base.py:324: UserWarning: Trying to unpickle estimator LabelBinarizer from version 1.1.3 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\giord\miniconda3\envs\bias\lib\site-packages\sklearn\base.py:324: UserWarning: Trying to unpickle estimator MLPClassifier from version 1.1.3 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\giord\miniconda3\envs\bias\lib\site-packages\sklearn\base.py:324: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.1.3 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\giord\miniconda3\envs\bias\lib\site-packages\sklearn\base.py:324: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.1.3 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
data = pd.read_csv('data/bias_symptoms.csv', index_col=[0,1])

# %%
data.index = data.index.droplevel(0)

# %%
# AUC

sp_mlp_train = []
sp_rf_train = []
sp_xgb_train = []
sp_mlp_test = []
sp_rf_test = []
sp_xgb_test = []

eo_mlp_train = []
eo_rf_train = []
eo_xgb_train = []
eo_mlp_test = []
eo_rf_test = []
eo_xgb_test = []

ao_mlp_train = []
ao_rf_train = []
ao_xgb_train = []
ao_mlp_test = []
ao_rf_test = []
ao_xgb_test = []

# F1 Score

sp_mlp_train_f1 = []
sp_rf_train_f1 = []
sp_xgb_train_f1 = []
sp_mlp_test_f1 = []
sp_rf_test_f1 = []
sp_xgb_test_f1 = []

eo_mlp_train_f1 = []
eo_rf_train_f1 = []
eo_xgb_train_f1 = []
eo_mlp_test_f1 = []
eo_rf_test_f1 = []
eo_xgb_test_f1 = []

ao_mlp_train_f1 = []
ao_rf_train_f1 = []
ao_xgb_train_f1 = []
ao_mlp_test_f1 = []
ao_rf_test_f1 = []
ao_xgb_test_f1 = []

# Accuracy

sp_mlp_train_acc = []
sp_rf_train_acc = []
sp_xgb_train_acc = []
sp_mlp_test_acc = []
sp_rf_test_acc = []
sp_xgb_test_acc = []

eo_mlp_train_acc = []
eo_rf_train_acc = []
eo_xgb_train_acc = []
eo_mlp_test_acc = []
eo_rf_test_acc = []
eo_xgb_test_acc = []

ao_mlp_train_acc = []
ao_rf_train_acc = []
ao_xgb_train_acc = []
ao_mlp_test_acc = []
ao_rf_test_acc = []
ao_xgb_test_acc = []


labels = ["statistical_parity", "equal_opportunity", "average_odds"]

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
for itrain, itest in kfold.split(data.index.unique().values):
    train_index = data.index.unique()[itrain]
    test_index = data.index.unique()[itest]
    print(train_index)
    print(test_index)
    train = data.loc[train_index]
    test = data.loc[test_index]

    mlp.fit(train.drop(columns=labels), train[labels])
    rf.fit(train.drop(columns=labels), train[labels])
    xgb.fit(train.drop(columns=labels), train[labels])

    mlp_train = mlp.predict_proba(train.drop(columns=labels))
    rf_train = rf.predict_proba(train.drop(columns=labels))
    xgb_train = xgb.predict_proba(train.drop(columns=labels))
    mlp_test = mlp.predict_proba(test.drop(columns=labels))
    rf_test = rf.predict_proba(test.drop(columns=labels))
    xgb_test = xgb.predict_proba(test.drop(columns=labels))

    mlp_train_pred = mlp.predict(train.drop(columns=labels))
    rf_train_pred = rf.predict(train.drop(columns=labels))
    xgb_train_pred = xgb.predict(train.drop(columns=labels))
    mlp_test_pred = mlp.predict(test.drop(columns=labels))
    rf_test_pred = rf.predict(test.drop(columns=labels))
    xgb_test_pred = xgb.predict(test.drop(columns=labels))

    sp_mlp_train.append(roc_auc_score(train["statistical_parity"], mlp_train[:, 0]))
    sp_rf_train.append(roc_auc_score(train["statistical_parity"], rf_train[0][:, 1]))
    sp_xgb_train.append(roc_auc_score(train["statistical_parity"], xgb_train[:, 0]))
    sp_mlp_test.append(roc_auc_score(test["statistical_parity"], mlp_test[:, 0]))
    sp_rf_test.append(roc_auc_score(test["statistical_parity"], rf_test[0][:, 1]))
    sp_xgb_test.append(roc_auc_score(test["statistical_parity"], xgb_test[:, 0]))

    eo_mlp_train.append(roc_auc_score(train["equal_opportunity"], mlp_train[:, 1]))
    eo_rf_train.append(roc_auc_score(train["equal_opportunity"], rf_train[1][:, 1]))
    eo_xgb_train.append(roc_auc_score(train["equal_opportunity"], xgb_train[:, 1]))
    eo_mlp_test.append(roc_auc_score(test["equal_opportunity"], mlp_test[:, 1]))
    eo_rf_test.append(roc_auc_score(test["equal_opportunity"], rf_test[1][:, 1]))
    eo_xgb_test.append(roc_auc_score(test["equal_opportunity"], xgb_test[:, 1]))

    ao_mlp_train.append(roc_auc_score(train["average_odds"], mlp_train[:, 2]))
    ao_rf_train.append(roc_auc_score(train["average_odds"], rf_train[2][:, 1]))
    ao_xgb_train.append(roc_auc_score(train["average_odds"], xgb_train[:, 2]))
    ao_mlp_test.append(roc_auc_score(test["average_odds"], mlp_test[:, 2]))
    ao_rf_test.append(roc_auc_score(test["average_odds"], rf_test[2][:, 1]))
    ao_xgb_test.append(roc_auc_score(test["average_odds"], xgb_test[:, 2]))

    sp_mlp_train_f1.append(f1_score(train["statistical_parity"], mlp_train_pred[:, 0]))
    sp_rf_train_f1.append(f1_score(train["statistical_parity"], rf_train_pred[:, 0]))
    sp_xgb_train_f1.append(f1_score(train["statistical_parity"], xgb_train_pred[:, 0]))
    sp_mlp_test_f1.append(f1_score(test["statistical_parity"], mlp_test_pred[:, 0]))
    sp_rf_test_f1.append(f1_score(test["statistical_parity"], rf_test_pred[:, 0]))
    sp_xgb_test_f1.append(f1_score(test["statistical_parity"], xgb_test_pred[:, 0]))

    eo_mlp_train_f1.append(f1_score(train["equal_opportunity"], mlp_train_pred[:, 1]))
    eo_rf_train_f1.append(f1_score(train["equal_opportunity"], rf_train_pred[:, 1]))
    eo_xgb_train_f1.append(f1_score(train["equal_opportunity"], xgb_train_pred[:, 1]))
    eo_mlp_test_f1.append(f1_score(test["equal_opportunity"], mlp_test_pred[:, 1]))
    eo_rf_test_f1.append(f1_score(test["equal_opportunity"], rf_test_pred[:, 1]))
    eo_xgb_test_f1.append(f1_score(test["equal_opportunity"], xgb_test_pred[:, 1]))

    ao_mlp_train_f1.append(f1_score(train["average_odds"], mlp_train_pred[:, 2]))
    ao_rf_train_f1.append(f1_score(train["average_odds"], rf_train_pred[:, 2]))
    ao_xgb_train_f1.append(f1_score(train["average_odds"], xgb_train_pred[:, 2]))
    ao_mlp_test_f1.append(f1_score(test["average_odds"], mlp_test_pred[:, 2]))
    ao_rf_test_f1.append(f1_score(test["average_odds"], rf_test_pred[:, 2]))
    ao_xgb_test_f1.append(f1_score(test["average_odds"], xgb_test_pred[:, 2]))

    sp_mlp_train_acc.append(accuracy_score(train["statistical_parity"], mlp_train_pred[:, 0]))
    sp_rf_train_acc.append(accuracy_score(train["statistical_parity"], rf_train_pred[:, 0]))
    sp_xgb_train_acc.append(accuracy_score(train["statistical_parity"], xgb_train_pred[:, 0]))
    sp_mlp_test_acc.append(accuracy_score(test["statistical_parity"], mlp_test_pred[:, 0]))
    sp_rf_test_acc.append(accuracy_score(test["statistical_parity"], rf_test_pred[:, 0]))
    sp_xgb_test_acc.append(accuracy_score(test["statistical_parity"], xgb_test_pred[:, 0]))

    eo_mlp_train_acc.append(accuracy_score(train["equal_opportunity"], mlp_train_pred[:, 1]))
    eo_rf_train_acc.append(accuracy_score(train["equal_opportunity"], rf_train_pred[:, 1]))
    eo_xgb_train_acc.append(accuracy_score(train["equal_opportunity"], xgb_train_pred[:, 1]))
    eo_mlp_test_acc.append(accuracy_score(test["equal_opportunity"], mlp_test_pred[:, 1]))
    eo_rf_test_acc.append(accuracy_score(test["equal_opportunity"], rf_test_pred[:, 1]))
    eo_xgb_test_acc.append(accuracy_score(test["equal_opportunity"], xgb_test_pred[:, 1]))

    ao_mlp_train_acc.append(accuracy_score(train["average_odds"], mlp_train_pred[:, 2]))
    ao_rf_train_acc.append(accuracy_score(train["average_odds"], rf_train_pred[:, 2]))
    ao_xgb_train_acc.append(accuracy_score(train["average_odds"], xgb_train_pred[:, 2]))
    ao_mlp_test_acc.append(accuracy_score(test["average_odds"], mlp_test_pred[:, 2]))
    ao_rf_test_acc.append(accuracy_score(test["average_odds"], rf_test_pred[:, 2]))
    ao_xgb_test_acc.append(accuracy_score(test["average_odds"], xgb_test_pred[:, 2]))
# Out:
# Index(['cmc', 'compas', 'credit', 'drug', 'german', 'health', 'hearth', 'law',
#        'medical', 'obesity', 'park', 'resyduo', 'wine'],
#       dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'crime', 'student'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'compas', 'credit', 'crime', 'drug',
#        'german', 'hearth', 'law', 'obesity', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['health', 'medical', 'park', 'resyduo'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'compas', 'credit', 'crime', 'drug', 'german',
#        'health', 'law', 'medical', 'obesity', 'park', 'resyduo', 'student'],
#       dtype='object', name='data')
# Index(['cmc', 'hearth', 'wine'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'compas', 'crime', 'drug', 'health',
#        'hearth', 'medical', 'obesity', 'park', 'resyduo', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['credit', 'german', 'law'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'credit', 'crime', 'german', 'health',
#        'hearth', 'law', 'medical', 'park', 'resyduo', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['compas', 'drug', 'obesity'], dtype='object', name='data')

# %%
def get_full_metrics(sp_mlp_train, sp_rf_train, sp_xgb_train, sp_mlp_test, sp_rf_test, sp_xgb_test, eo_mlp_train, eo_rf_train, eo_xgb_train, eo_mlp_test, eo_rf_test, eo_xgb_test, ao_mlp_train, ao_rf_train, ao_xgb_train, ao_mlp_test, ao_rf_test, ao_xgb_test):
    df_sp = pd.DataFrame(
        {"MLP": sp_mlp_train, "RF": sp_rf_train, "XGB": sp_xgb_train, "Fold": "Train"}
    )
    df_sp = pd.concat(
        [
            df_sp,
            pd.DataFrame(
                {"MLP": sp_mlp_test, "RF": sp_rf_test, "XGB": sp_xgb_test, "Fold": "Test"}
            ),
        ]
    )
    df_sp = pd.melt(df_sp, id_vars=["Fold"], var_name="Model", value_name="Score")
    df_sp["Metric"] = "Statistical Parity"
    df_eo = pd.DataFrame(
        {"MLP": eo_mlp_train, "RF": eo_rf_train, "XGB": eo_xgb_train, "Fold": "Train"}
    )
    df_eo = pd.concat(
        [
            df_eo,
            pd.DataFrame(
                {"MLP": eo_mlp_test, "RF": eo_rf_test, "XGB": eo_xgb_test, "Fold": "Test"}
            ),
        ]
    )
    df_eo = pd.melt(df_eo, id_vars=["Fold"], var_name="Model", value_name="Score")
    df_eo["Metric"] = "Equal Opportunity"

    df_ao = pd.DataFrame(
        {"MLP": ao_mlp_train, "RF": ao_rf_train, "XGB": ao_xgb_train, "Fold": "Train"}
    )
    df_ao = pd.concat(
        [
            df_ao,
            pd.DataFrame(
                {"MLP": ao_mlp_test, "RF": ao_rf_test, "XGB": ao_xgb_test, "Fold": "Test"}
            ),
        ]
    )
    df_ao = pd.melt(df_ao, id_vars=["Fold"], var_name="Model", value_name="Score")
    df_ao["Metric"] = "Average Odds"
    auc = pd.concat([df_sp, df_eo, df_ao])
    return auc

# %%
auc = get_full_metrics(sp_mlp_train, sp_rf_train, sp_xgb_train, sp_mlp_test, sp_rf_test, sp_xgb_test, eo_mlp_train, eo_rf_train, eo_xgb_train, eo_mlp_test, eo_rf_test, eo_xgb_test, ao_mlp_train, ao_rf_train, ao_xgb_train, ao_mlp_test, ao_rf_test, ao_xgb_test)
g = sns.FacetGrid(auc, col="Metric", height=5, aspect=1)
g.map(sns.boxplot, "Model", "Score", "Fold", hue_order=["Train", "Test"], palette=sns.color_palette()[:2])
g.add_legend()
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle('AUC Score')
g.fig.savefig('figs/auc.png', dpi=300)
plt.show()
# Out:
# c:\Users\giord\miniconda3\envs\bias\lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
f1 = get_full_metrics(sp_mlp_train_f1, sp_rf_train_f1, sp_xgb_train_f1, sp_mlp_test_f1, sp_rf_test_f1, sp_xgb_test_f1, eo_mlp_train_f1, eo_rf_train_f1, eo_xgb_train_f1, eo_mlp_test_f1, eo_rf_test_f1, eo_xgb_test_f1, ao_mlp_train_f1, ao_rf_train_f1, ao_xgb_train_f1, ao_mlp_test_f1, ao_rf_test_f1, ao_xgb_test_f1)
g = sns.FacetGrid(f1, col="Metric", height=5, aspect=1)
g.map(
    sns.boxplot,
    "Model",
    "Score",
    "Fold",
    hue_order=["Train", "Test"],
    palette=sns.color_palette()[:2],
)
g.add_legend()
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("F1 Score")
g.fig.savefig("figs/f1.png", dpi=300)
plt.show()
# Out:
# c:\Users\giord\miniconda3\envs\bias\lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
acc = get_full_metrics(sp_mlp_train_acc, sp_rf_train_acc, sp_xgb_train_acc, sp_mlp_test_acc, sp_rf_test_acc, sp_xgb_test_acc, eo_mlp_train_acc, eo_rf_train_acc, eo_xgb_train_acc, eo_mlp_test_acc, eo_rf_test_acc, eo_xgb_test_acc, ao_mlp_train_acc, ao_rf_train_acc, ao_xgb_train_acc, ao_mlp_test_acc, ao_rf_test_acc, ao_xgb_test_acc)
g = sns.FacetGrid(acc, col="Metric", height=5, aspect=1)
g.map(
    sns.boxplot,
    "Model",
    "Score",
    "Fold",
    hue_order=["Train", "Test"],
    palette=sns.color_palette()[:2],
)
g.add_legend()
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Accuracy Score")
g.fig.savefig("figs/acc.png", dpi=300)
plt.show()
# Out:
# c:\Users\giord\miniconda3\envs\bias\lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Symptoms significance

# %%
meta = pd.read_csv('data/metafeatures.csv', index_col=[0,1])
meta.index = meta.index.droplevel(0)

# %%
# AUC

sp_xgb_meta = []
eo_xgb_meta = []
ao_xgb_meta = []

# F1 Score

sp_xgb_test_f1 = []
eo_xgb_test_f1 = []
ao_xgb_test_f1 = []

# Accuracy

meta_sp_xgb_test_acc = []
meta_eo_xgb_test_acc = []
meta_ao_xgb_test_acc = []

labels = ["statistical_parity", "equal_opportunity", "average_odds"]

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
for itrain, itest in kfold.split(meta.index.unique().values):
    train_index = meta.index.unique()[itrain]
    test_index = meta.index.unique()[itest]
    print(train_index)
    print(test_index)
    train = meta.loc[train_index]
    test = meta.loc[test_index]
    xgb.fit(train.drop(columns=labels), train[labels])

    xgb_test = xgb.predict_proba(test.drop(columns=labels))
    xgb_test_pred = xgb.predict(test.drop(columns=labels))

    sp_xgb_meta.append(roc_auc_score(test["statistical_parity"], xgb_test[:, 0]))
    eo_xgb_meta.append(roc_auc_score(test["equal_opportunity"], xgb_test[:, 1]))
    ao_xgb_meta.append(roc_auc_score(test["average_odds"], xgb_test[:, 2]))

    meta_sp_xgb_test_acc.append(
        accuracy_score(test["statistical_parity"], xgb_test_pred[:, 0])
    )
    meta_eo_xgb_test_acc.append(
        accuracy_score(test["equal_opportunity"], xgb_test_pred[:, 1])
    )
    meta_ao_xgb_test_acc.append(
        accuracy_score(test["average_odds"], xgb_test_pred[:, 2])
    )
# Out:
# Index(['cmc', 'compas', 'credit', 'drug', 'german', 'health', 'hearth', 'law',
#        'medical', 'obesity', 'park', 'resyduo', 'wine'],
#       dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'crime', 'student'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'compas', 'credit', 'crime', 'drug',
#        'german', 'hearth', 'law', 'obesity', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['health', 'medical', 'park', 'resyduo'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'compas', 'credit', 'crime', 'drug', 'german',
#        'health', 'law', 'medical', 'obesity', 'park', 'resyduo', 'student'],
#       dtype='object', name='data')
# Index(['cmc', 'hearth', 'wine'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'compas', 'crime', 'drug', 'health',
#        'hearth', 'medical', 'obesity', 'park', 'resyduo', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['credit', 'german', 'law'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'credit', 'crime', 'german', 'health',
#        'hearth', 'law', 'medical', 'park', 'resyduo', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['compas', 'drug', 'obesity'], dtype='object', name='data')

# %%
both = pd.read_csv('data/all_features.csv', index_col=[0,1])
both.index = both.index.droplevel(0)

# %%
all_sp_xgb_test_acc = []
all_eo_xgb_test_acc = []
all_ao_xgb_test_acc = []

all_sp_xgb_test_auc = []
all_eo_xgb_test_auc = []
all_ao_xgb_test_auc = []

labels = ["statistical_parity", "equal_opportunity", "average_odds"]

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
for itrain, itest in kfold.split(both.index.unique().values):
    train_index = both.index.unique()[itrain]
    test_index = both.index.unique()[itest]
    print(train_index)
    print(test_index)
    train = both.loc[train_index]
    test = both.loc[test_index]
    xgb.fit(train.drop(columns=labels), train[labels])

    xgb_test = xgb.predict_proba(test.drop(columns=labels))
    xgb_test_pred = xgb.predict(test.drop(columns=labels))

    all_sp_xgb_test_auc.append(
        roc_auc_score(test["statistical_parity"], xgb_test[:, 0])
    )
    all_eo_xgb_test_auc.append(roc_auc_score(test["equal_opportunity"], xgb_test[:, 1]))
    all_ao_xgb_test_auc.append(roc_auc_score(test["average_odds"], xgb_test[:, 2]))

    all_sp_xgb_test_acc.append(
        accuracy_score(test["statistical_parity"], xgb_test_pred[:, 0])
    )
    all_eo_xgb_test_acc.append(
        accuracy_score(test["equal_opportunity"], xgb_test_pred[:, 1])
    )
    all_ao_xgb_test_acc.append(
        accuracy_score(test["average_odds"], xgb_test_pred[:, 2])
    )
# Out:
# Index(['cmc', 'compas', 'credit', 'drug', 'german', 'health', 'hearth', 'law',
#        'medical', 'obesity', 'park', 'resyduo', 'wine'],
#       dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'crime', 'student'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'compas', 'credit', 'crime', 'drug',
#        'german', 'hearth', 'law', 'obesity', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['health', 'medical', 'park', 'resyduo'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'compas', 'credit', 'crime', 'drug', 'german',
#        'health', 'law', 'medical', 'obesity', 'park', 'resyduo', 'student'],
#       dtype='object', name='data')
# Index(['cmc', 'hearth', 'wine'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'compas', 'crime', 'drug', 'health',
#        'hearth', 'medical', 'obesity', 'park', 'resyduo', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['credit', 'german', 'law'], dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'cmc', 'credit', 'crime', 'german', 'health',
#        'hearth', 'law', 'medical', 'park', 'resyduo', 'student', 'wine'],
#       dtype='object', name='data')
# Index(['compas', 'drug', 'obesity'], dtype='object', name='data')

# %%
def data_comparison(symp_sp, meta_sp, all_sp, symp_eo, meta_eo, all_eo, symp_ao, meta_ao, all_ao, title):
    stat_par = pd.DataFrame(
        {
            "Symp": symp_sp,
            "Meta": meta_sp,
            "Both": all_sp,
        }
    )
    equal_opp = pd.DataFrame(
        {
            "Symp": symp_eo,
            "Meta": meta_eo,
            "Both": all_eo,
        }
    )

    avg_odds = pd.DataFrame(
        {
            "Symp": symp_ao,
            "Meta": meta_ao,
            "Both": all_ao,
        }
    )
    fig, ax = plt.subplots(1, 3, figsize=(10, 5), sharey=True)
    sns.boxplot(data=stat_par, ax=ax[0])
    sns.boxplot(data=equal_opp, ax=ax[1])
    sns.boxplot(data=avg_odds, ax=ax[2])
    ax[0].set_title("Statistical parity")
    ax[1].set_title("Equal opportunity")
    ax[2].set_title("Average odds")
    plt.suptitle(title)
    plt.tight_layout()
    plt.savefig(f"figs/data_evaluation_{title}.png", dpi=300)
    plt.show()

# %%
data_comparison(sp_xgb_test_acc, meta_sp_xgb_test_acc, all_sp_xgb_test_acc, eo_xgb_test_acc, meta_eo_xgb_test_acc, all_eo_xgb_test_acc, ao_xgb_test_acc, meta_ao_xgb_test_acc, all_ao_xgb_test_acc, "Accuracy")

# %%
data_comparison(
    sp_xgb_test,
    sp_xgb_meta,
    all_sp_xgb_test_auc,
    eo_xgb_test,
    eo_xgb_meta,
    all_eo_xgb_test_auc,
    ao_xgb_test,
    ao_xgb_meta,
    all_ao_xgb_test_auc,
    "AUC",
)

# %%
from catboost import CatBoostClassifier

# %%
cat = CatBoostClassifier(
    loss_function="MultiLogloss", eval_metric="Accuracy"
)

# %%
all_sp_xgb_test_acc = []
all_eo_xgb_test_acc = []
all_ao_xgb_test_acc = []

all_sp_xgb_test_auc = []
all_eo_xgb_test_auc = []
all_ao_xgb_test_auc = []

labels = ["statistical_parity", "equal_opportunity", "average_odds"]

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
for itrain, itest in kfold.split(data.index.unique().values):
    train_index = both.index.unique()[itrain]
    test_index = both.index.unique()[itest]
    print(train_index)
    print(test_index)
    train = both.loc[train_index]
    test = both.loc[test_index]
    cat.fit(train.drop(columns=labels), train[labels])

    xgb_test = cat.predict_proba(test.drop(columns=labels))
    xgb_test_pred = cat.predict(test.drop(columns=labels))

    all_sp_xgb_test_auc.append(
        roc_auc_score(test["statistical_parity"], xgb_test[:, 0])
    )
    all_eo_xgb_test_auc.append(roc_auc_score(test["equal_opportunity"], xgb_test[:, 1]))
    all_ao_xgb_test_auc.append(roc_auc_score(test["average_odds"], xgb_test[:, 2]))

    all_sp_xgb_test_acc.append(
        accuracy_score(test["statistical_parity"], xgb_test_pred[:, 0])
    )
    all_eo_xgb_test_acc.append(
        accuracy_score(test["equal_opportunity"], xgb_test_pred[:, 1])
    )
    all_ao_xgb_test_acc.append(
        accuracy_score(test["average_odds"], xgb_test_pred[:, 2])
    )
# Out:
# Index(['cmc', 'compas', 'credit', 'drug', 'german', 'health', 'hearth', 'law',
#        'medical', 'obesity', 'park', 'resyduo', 'wine'],
#       dtype='object', name='data')
# Index(['adult', 'arrhythmia', 'crime', 'student'], dtype='object', name='data')
# Learning rate set to 0.014817
# 0:	learn: 0.5371477	total: 11.6ms	remaining: 11.6s
# 1:	learn: 0.5345858	total: 23.6ms	remaining: 11.8s
# 2:	learn: 0.5431255	total: 36.3ms	remaining: 12.1s
# 3:	learn: 0.5418446	total: 79.5ms	remaining: 19.8s
# 4:	learn: 0.5204953	total: 94.7ms	remaining: 18.8s
# 5:	learn: 0.5209223	total: 105ms	remaining: 17.4s
# 6:	learn: 0.5179334	total: 115ms	remaining: 16.3s
# 7:	learn: 0.5384287	total: 124ms	remaining: 15.3s
# 8:	learn: 0.5426985	total: 135ms	remaining: 14.9s
# 9:	learn: 0.5469684	total: 144ms	remaining: 14.2s
# 154:	learn: 0.5969257	total: 1.69s	remaining: 9.23s
# 155:	learn: 0.5964987	total: 1.71s	remaining: 9.23s
# 156:	learn: 0.5973527	total: 1.72s	remaining: 9.22s
# 157:	learn: 0.5977797	total: 1.73s	remaining: 9.2s
# 158:	learn: 0.5990606	total: 1.74s	remaining: 9.2s
# 159:	learn: 0.5990606	total: 1.75s	remaining: 9.18s
# 160:	learn: 0.5999146	total: 1.76s	remaining: 9.17s
# 161:	learn: 0.5999146	total: 1.77s	remaining: 9.14s
# 162:	learn: 0.5994876	total: 1.78s	remaining: 9.13s
# 163:	learn: 0.5994876	total: 1.79s	remaining: 9.11s
# 164:	learn: 0.5994876	total: 1.8s	remaining: 9.09s
# 165:	learn: 0.5994876	total: 1.8s	remaining: 9.07s
# 166:	learn: 0.6003416	total: 1.81s	remaining: 9.05s
# 167:	learn: 0.6003416	total: 1.82s	remaining: 9.04s
# 168:	learn: 0.6007686	total: 1.83s	remaining: 9.02s
# 169:	learn: 0.6007686	total: 1.84s	remaining: 9s
# 170:	learn: 0.6016225	total: 1.85s	remaining: 8.98s
# 171:	learn: 0.6016225	total: 1.86s	remaining: 8.97s
# 172:	learn: 0.6016225	total: 1.87s	remaining: 8.95s
# 173:	learn: 0.6024765	total: 1.88s	remaining: 8.93s
# 174:	learn: 0.6029035	total: 1.89s	remaining: 8.91s
# 175:	learn: 0.6024765	total: 1.9s	remaining: 8.89s
# 176:	learn: 0.6020495	total: 1.91s	remaining: 8.88s
# 177:	learn: 0.6020495	total: 1.92s	remaining: 8.87s
# 178:	learn: 0.6029035	total: 1.93s	remaining: 8.86s
# 179:	learn: 0.6024765	total: 1.94s	remaining: 8.85s
# 180:	learn: 0.6033305	total: 1.95s	remaining: 8.83s
# 181:	learn: 0.6024765	total: 1.96s	remaining: 8.82s
# 182:	learn: 0.6029035	total: 1.97s	remaining: 8.81s
# 183:	learn: 0.6029035	total: 1.98s	remaining: 8.79s
# 184:	learn: 0.6029035	total: 1.99s	remaining: 8.77s
# 185:	learn: 0.6029035	total: 2s	remaining: 8.75s
# 186:	learn: 0.6037575	total: 2.01s	remaining: 8.74s
# 187:	learn: 0.6033305	total: 2.02s	remaining: 8.73s
# 188:	learn: 0.6041845	total: 2.03s	remaining: 8.71s
# 189:	learn: 0.6041845	total: 2.04s	remaining: 8.7s
# 190:	learn: 0.6046114	total: 2.05s	remaining: 8.68s
# 191:	learn: 0.6050384	total: 2.06s	remaining: 8.67s
# 192:	learn: 0.6041845	total: 2.07s	remaining: 8.65s
# 193:	learn: 0.6037575	total: 2.08s	remaining: 8.63s
# 194:	learn: 0.6041845	total: 2.09s	remaining: 8.62s
# 195:	learn: 0.6041845	total: 2.1s	remaining: 8.6s
# 196:	learn: 0.6041845	total: 2.11s	remaining: 8.59s
# 197:	learn: 0.6046114	total: 2.12s	remaining: 8.57s
# 198:	learn: 0.6054654	total: 2.12s	remaining: 8.55s
# 199:	learn: 0.6046114	total: 2.13s	remaining: 8.53s
# 809:	learn: 0.6801879	total: 7.94s	remaining: 1.86s
# 810:	learn: 0.6801879	total: 7.95s	remaining: 1.85s
# 811:	learn: 0.6801879	total: 7.96s	remaining: 1.84s
# 812:	learn: 0.6797609	total: 7.97s	remaining: 1.83s
# 813:	learn: 0.6797609	total: 7.98s	remaining: 1.82s
# 814:	learn: 0.6797609	total: 7.99s	remaining: 1.81s
# 815:	learn: 0.6797609	total: 8s	remaining: 1.8s
# 816:	learn: 0.6806149	total: 8s	remaining: 1.79s
# 817:	learn: 0.6801879	total: 8.01s	remaining: 1.78s
# 818:	learn: 0.6806149	total: 8.02s	remaining: 1.77s
# 819:	learn: 0.6810418	total: 8.03s	remaining: 1.76s
# 820:	learn: 0.6810418	total: 8.04s	remaining: 1.75s
# 821:	learn: 0.6810418	total: 8.05s	remaining: 1.74s
# 822:	learn: 0.6814688	total: 8.06s	remaining: 1.73s
# 823:	learn: 0.6814688	total: 8.06s	remaining: 1.72s
# 824:	learn: 0.6814688	total: 8.07s	remaining: 1.71s
# 825:	learn: 0.6814688	total: 8.08s	remaining: 1.7s
# 826:	learn: 0.6814688	total: 8.09s	remaining: 1.69s
# 827:	learn: 0.6818958	total: 8.1s	remaining: 1.68s
# 828:	learn: 0.6814688	total: 8.11s	remaining: 1.67s
# 829:	learn: 0.6818958	total: 8.12s	remaining: 1.66s
# 830:	learn: 0.6823228	total: 8.13s	remaining: 1.65s
# 831:	learn: 0.6818958	total: 8.14s	remaining: 1.64s
# 832:	learn: 0.6818958	total: 8.15s	remaining: 1.63s
# 833:	learn: 0.6818958	total: 8.15s	remaining: 1.62s
# 834:	learn: 0.6818958	total: 8.16s	remaining: 1.61s
# 835:	learn: 0.6823228	total: 8.17s	remaining: 1.6s
# 836:	learn: 0.6823228	total: 8.18s	remaining: 1.59s
# 837:	learn: 0.6823228	total: 8.19s	remaining: 1.58s
# 838:	learn: 0.6831768	total: 8.2s	remaining: 1.57s
# 839:	learn: 0.6831768	total: 8.21s	remaining: 1.56s
# 840:	learn: 0.6831768	total: 8.21s	remaining: 1.55s
# 841:	learn: 0.6827498	total: 8.22s	remaining: 1.54s
# 842:	learn: 0.6836038	total: 8.23s	remaining: 1.53s
# 843:	learn: 0.6831768	total: 8.24s	remaining: 1.52s
# 844:	learn: 0.6836038	total: 8.25s	remaining: 1.51s
# 845:	learn: 0.6840307	total: 8.26s	remaining: 1.5s
# 846:	learn: 0.6840307	total: 8.27s	remaining: 1.49s
# 847:	learn: 0.6840307	total: 8.28s	remaining: 1.48s
# 848:	learn: 0.6840307	total: 8.28s	remaining: 1.47s
# 849:	learn: 0.6840307	total: 8.29s	remaining: 1.46s
# 850:	learn: 0.6840307	total: 8.3s	remaining: 1.45s
# 851:	learn: 0.6840307	total: 8.31s	remaining: 1.44s
# 852:	learn: 0.6840307	total: 8.32s	remaining: 1.43s
# 853:	learn: 0.6840307	total: 8.33s	remaining: 1.42s
# 854:	learn: 0.6840307	total: 8.34s	remaining: 1.41s
# 855:	learn: 0.6844577	total: 8.35s	remaining: 1.4s
# 856:	learn: 0.6844577	total: 8.36s	remaining: 1.39s
# 857:	learn: 0.6844577	total: 8.37s	remaining: 1.38s
# 858:	learn: 0.6844577	total: 8.38s	remaining: 1.37s
# 859:	learn: 0.6840307	total: 8.38s	remaining: 1.36s
# 860:	learn: 0.6840307	total: 8.39s	remaining: 1.35s
# 861:	learn: 0.6840307	total: 8.4s	remaining: 1.34s
# 862:	learn: 0.6840307	total: 8.41s	remaining: 1.33s
# 863:	learn: 0.6840307	total: 8.42s	remaining: 1.32s
# 864:	learn: 0.6840307	total: 8.44s	remaining: 1.32s
# 865:	learn: 0.6844577	total: 8.45s	remaining: 1.31s
# 866:	learn: 0.6844577	total: 8.46s	remaining: 1.3s
# 867:	learn: 0.6844577	total: 8.47s	remaining: 1.29s
# 868:	learn: 0.6844577	total: 8.48s	remaining: 1.28s
# 869:	learn: 0.6848847	total: 8.49s	remaining: 1.27s
# 870:	learn: 0.6853117	total: 8.5s	remaining: 1.26s
# 871:	learn: 0.6853117	total: 8.51s	remaining: 1.25s
# 872:	learn: 0.6853117	total: 8.52s	remaining: 1.24s
# 873:	learn: 0.6853117	total: 8.53s	remaining: 1.23s
# 874:	learn: 0.6861657	total: 8.54s	remaining: 1.22s
# 875:	learn: 0.6861657	total: 8.54s	remaining: 1.21s
# 876:	learn: 0.6853117	total: 8.55s	remaining: 1.2s
# 877:	learn: 0.6853117	total: 8.56s	remaining: 1.19s
# 878:	learn: 0.6853117	total: 8.57s	remaining: 1.18s
# 879:	learn: 0.6853117	total: 8.58s	remaining: 1.17s
# 880:	learn: 0.6853117	total: 8.59s	remaining: 1.16s
# 881:	learn: 0.6865927	total: 8.6s	remaining: 1.15s
# 882:	learn: 0.6861657	total: 8.61s	remaining: 1.14s
# 883:	learn: 0.6861657	total: 8.62s	remaining: 1.13s
# 884:	learn: 0.6861657	total: 8.62s	remaining: 1.12s
# 885:	learn: 0.6870196	total: 8.63s	remaining: 1.11s
# 886:	learn: 0.6874466	total: 8.64s	remaining: 1.1s
# 887:	learn: 0.6874466	total: 8.65s	remaining: 1.09s
# 888:	learn: 0.6874466	total: 8.66s	remaining: 1.08s
# 889:	learn: 0.6878736	total: 8.67s	remaining: 1.07s
# 890:	learn: 0.6878736	total: 8.68s	remaining: 1.06s
# 891:	learn: 0.6883006	total: 8.69s	remaining: 1.05s
# 892:	learn: 0.6887276	total: 8.7s	remaining: 1.04s
# 893:	learn: 0.6887276	total: 8.71s	remaining: 1.03s
# 894:	learn: 0.6883006	total: 8.72s	remaining: 1.02s
# 895:	learn: 0.6883006	total: 8.72s	remaining: 1.01s
# 896:	learn: 0.6883006	total: 8.73s	remaining: 1s
# 897:	learn: 0.6883006	total: 8.74s	remaining: 993ms
# 898:	learn: 0.6883006	total: 8.75s	remaining: 983ms
# 899:	learn: 0.6883006	total: 8.76s	remaining: 973ms
# 900:	learn: 0.6887276	total: 8.77s	remaining: 963ms
# 901:	learn: 0.6887276	total: 8.78s	remaining: 954ms
# 902:	learn: 0.6895816	total: 8.79s	remaining: 944ms
# 766:	learn: 0.7979508	total: 8.08s	remaining: 2.45s
# 767:	learn: 0.7983607	total: 8.09s	remaining: 2.44s
# 768:	learn: 0.7983607	total: 8.1s	remaining: 2.43s
# 769:	learn: 0.7983607	total: 8.12s	remaining: 2.42s
# 770:	learn: 0.7987705	total: 8.13s	remaining: 2.41s
# 771:	learn: 0.7987705	total: 8.14s	remaining: 2.4s
# 772:	learn: 0.7995902	total: 8.15s	remaining: 2.39s
# 773:	learn: 0.7995902	total: 8.16s	remaining: 2.38s
# 774:	learn: 0.7995902	total: 8.17s	remaining: 2.37s
# 775:	learn: 0.7995902	total: 8.18s	remaining: 2.36s
# 776:	learn: 0.7991803	total: 8.19s	remaining: 2.35s
# 777:	learn: 0.8000000	total: 8.21s	remaining: 2.34s
# 778:	learn: 0.8012295	total: 8.21s	remaining: 2.33s
# 779:	learn: 0.8016393	total: 8.23s	remaining: 2.32s
# 780:	learn: 0.8016393	total: 8.24s	remaining: 2.31s
# 781:	learn: 0.8020492	total: 8.25s	remaining: 2.3s
# 782:	learn: 0.8012295	total: 8.26s	remaining: 2.29s
# 783:	learn: 0.8020492	total: 8.27s	remaining: 2.28s
# 784:	learn: 0.8024590	total: 8.28s	remaining: 2.27s
# 785:	learn: 0.8024590	total: 8.29s	remaining: 2.26s
# 786:	learn: 0.8028689	total: 8.31s	remaining: 2.25s
# 787:	learn: 0.8024590	total: 8.32s	remaining: 2.24s
# 788:	learn: 0.8024590	total: 8.33s	remaining: 2.23s
# 789:	learn: 0.8032787	total: 8.34s	remaining: 2.22s
# 790:	learn: 0.8028689	total: 8.35s	remaining: 2.21s
# 791:	learn: 0.8040984	total: 8.36s	remaining: 2.2s
# 792:	learn: 0.8049180	total: 8.37s	remaining: 2.19s
# 793:	learn: 0.8045082	total: 8.38s	remaining: 2.17s
# 794:	learn: 0.8040984	total: 8.4s	remaining: 2.17s
# 795:	learn: 0.8040984	total: 8.41s	remaining: 2.15s
# 796:	learn: 0.8045082	total: 8.42s	remaining: 2.14s
# 797:	learn: 0.8045082	total: 8.43s	remaining: 2.13s
# 798:	learn: 0.8040984	total: 8.44s	remaining: 2.12s
# 799:	learn: 0.8045082	total: 8.45s	remaining: 2.11s
# 800:	learn: 0.8045082	total: 8.46s	remaining: 2.1s
# 801:	learn: 0.8053279	total: 8.47s	remaining: 2.09s
# 802:	learn: 0.8049180	total: 8.48s	remaining: 2.08s
# 803:	learn: 0.8057377	total: 8.5s	remaining: 2.07s
# 804:	learn: 0.8057377	total: 8.51s	remaining: 2.06s
# 805:	learn: 0.8057377	total: 8.52s	remaining: 2.05s
# 806:	learn: 0.8057377	total: 8.53s	remaining: 2.04s
# 807:	learn: 0.8057377	total: 8.54s	remaining: 2.03s
# 808:	learn: 0.8057377	total: 8.55s	remaining: 2.02s
# 809:	learn: 0.8057377	total: 8.57s	remaining: 2.01s
# 810:	learn: 0.8061475	total: 8.58s	remaining: 2s
# 811:	learn: 0.8057377	total: 8.59s	remaining: 1.99s
# 812:	learn: 0.8061475	total: 8.6s	remaining: 1.98s
# 813:	learn: 0.8061475	total: 8.61s	remaining: 1.97s
# 814:	learn: 0.8061475	total: 8.63s	remaining: 1.96s
# 815:	learn: 0.8065574	total: 8.64s	remaining: 1.95s
# 816:	learn: 0.8065574	total: 8.66s	remaining: 1.94s
# 817:	learn: 0.8065574	total: 8.67s	remaining: 1.93s
# 818:	learn: 0.8065574	total: 8.69s	remaining: 1.92s
# 819:	learn: 0.8069672	total: 8.7s	remaining: 1.91s
# 820:	learn: 0.8073770	total: 8.71s	remaining: 1.9s
# 821:	learn: 0.8069672	total: 8.72s	remaining: 1.89s
# 822:	learn: 0.8069672	total: 8.73s	remaining: 1.88s
# 823:	learn: 0.8073770	total: 8.75s	remaining: 1.87s
# 824:	learn: 0.8073770	total: 8.76s	remaining: 1.86s
# 825:	learn: 0.8073770	total: 8.77s	remaining: 1.85s
# 826:	learn: 0.8073770	total: 8.78s	remaining: 1.84s
# 827:	learn: 0.8081967	total: 8.79s	remaining: 1.83s
# 828:	learn: 0.8081967	total: 8.8s	remaining: 1.81s
# 829:	learn: 0.8081967	total: 8.81s	remaining: 1.8s
# 830:	learn: 0.8077869	total: 8.82s	remaining: 1.79s
# 831:	learn: 0.8077869	total: 8.83s	remaining: 1.78s
# 832:	learn: 0.8090164	total: 8.85s	remaining: 1.77s
# 833:	learn: 0.8090164	total: 8.86s	remaining: 1.76s
# 834:	learn: 0.8094262	total: 8.87s	remaining: 1.75s
# 835:	learn: 0.8094262	total: 8.88s	remaining: 1.74s
# 836:	learn: 0.8094262	total: 8.89s	remaining: 1.73s
# 837:	learn: 0.8090164	total: 8.9s	remaining: 1.72s
# 838:	learn: 0.8090164	total: 8.92s	remaining: 1.71s
# 839:	learn: 0.8090164	total: 8.93s	remaining: 1.7s
# 840:	learn: 0.8090164	total: 8.94s	remaining: 1.69s
# 841:	learn: 0.8090164	total: 8.95s	remaining: 1.68s
# 842:	learn: 0.8090164	total: 8.96s	remaining: 1.67s
# 843:	learn: 0.8094262	total: 8.98s	remaining: 1.66s
# 844:	learn: 0.8094262	total: 8.99s	remaining: 1.65s
# 845:	learn: 0.8094262	total: 9s	remaining: 1.64s
# 846:	learn: 0.8094262	total: 9.01s	remaining: 1.63s
# 847:	learn: 0.8102459	total: 9.03s	remaining: 1.62s
# 848:	learn: 0.8114754	total: 9.04s	remaining: 1.61s
# 849:	learn: 0.8114754	total: 9.05s	remaining: 1.6s
# 850:	learn: 0.8114754	total: 9.06s	remaining: 1.59s
# 851:	learn: 0.8110656	total: 9.07s	remaining: 1.58s
# 852:	learn: 0.8110656	total: 9.09s	remaining: 1.57s
# 853:	learn: 0.8110656	total: 9.1s	remaining: 1.55s
# 854:	learn: 0.8118852	total: 9.11s	remaining: 1.54s
# 855:	learn: 0.8118852	total: 9.12s	remaining: 1.53s
# 856:	learn: 0.8118852	total: 9.13s	remaining: 1.52s
# 857:	learn: 0.8127049	total: 9.14s	remaining: 1.51s
# 858:	learn: 0.8127049	total: 9.16s	remaining: 1.5s
# 859:	learn: 0.8131148	total: 9.17s	remaining: 1.49s
# 860:	learn: 0.8131148	total: 9.18s	remaining: 1.48s
# 861:	learn: 0.8131148	total: 9.19s	remaining: 1.47s
# 862:	learn: 0.8139344	total: 9.2s	remaining: 1.46s
# 863:	learn: 0.8143443	total: 9.21s	remaining: 1.45s
# 864:	learn: 0.8139344	total: 9.22s	remaining: 1.44s
# 865:	learn: 0.8139344	total: 9.23s	remaining: 1.43s
# 866:	learn: 0.8139344	total: 9.24s	remaining: 1.42s
# 867:	learn: 0.8139344	total: 9.25s	remaining: 1.41s
# 868:	learn: 0.8151639	total: 9.26s	remaining: 1.4s
# 869:	learn: 0.8147541	total: 9.27s	remaining: 1.39s
# 870:	learn: 0.8155738	total: 9.28s	remaining: 1.37s
# 871:	learn: 0.8151639	total: 9.29s	remaining: 1.36s
# 872:	learn: 0.8159836	total: 9.3s	remaining: 1.35s
# 873:	learn: 0.8163934	total: 9.31s	remaining: 1.34s
# 874:	learn: 0.8163934	total: 9.32s	remaining: 1.33s
# 875:	learn: 0.8163934	total: 9.33s	remaining: 1.32s
# 876:	learn: 0.8159836	total: 9.34s	remaining: 1.31s
# 877:	learn: 0.8159836	total: 9.35s	remaining: 1.3s
# 878:	learn: 0.8168033	total: 9.36s	remaining: 1.29s
# 879:	learn: 0.8163934	total: 9.37s	remaining: 1.28s
# 880:	learn: 0.8168033	total: 9.38s	remaining: 1.27s
# 881:	learn: 0.8168033	total: 9.39s	remaining: 1.26s
# 882:	learn: 0.8168033	total: 9.4s	remaining: 1.25s
# 883:	learn: 0.8184426	total: 9.41s	remaining: 1.24s
# 884:	learn: 0.8180328	total: 9.42s	remaining: 1.22s
# 885:	learn: 0.8184426	total: 9.43s	remaining: 1.21s
# 886:	learn: 0.8188525	total: 9.44s	remaining: 1.2s
# 887:	learn: 0.8200820	total: 9.45s	remaining: 1.19s
# 888:	learn: 0.8204918	total: 9.46s	remaining: 1.18s
# 889:	learn: 0.8209016	total: 9.47s	remaining: 1.17s
# 890:	learn: 0.8209016	total: 9.48s	remaining: 1.16s
# 891:	learn: 0.8204918	total: 9.5s	remaining: 1.15s
# 892:	learn: 0.8204918	total: 9.51s	remaining: 1.14s
# 893:	learn: 0.8209016	total: 9.52s	remaining: 1.13s
# 894:	learn: 0.8213115	total: 9.53s	remaining: 1.12s
# 895:	learn: 0.8217213	total: 9.53s	remaining: 1.11s
# 896:	learn: 0.8217213	total: 9.54s	remaining: 1.1s
# 897:	learn: 0.8221311	total: 9.55s	remaining: 1.08s
# 898:	learn: 0.8221311	total: 9.56s	remaining: 1.07s
# 899:	learn: 0.8221311	total: 9.57s	remaining: 1.06s
# 900:	learn: 0.8221311	total: 9.58s	remaining: 1.05s
# 901:	learn: 0.8221311	total: 9.59s	remaining: 1.04s
# 902:	learn: 0.8221311	total: 9.6s	remaining: 1.03s
# 903:	learn: 0.8217213	total: 9.62s	remaining: 1.02s
# 904:	learn: 0.8221311	total: 9.63s	remaining: 1.01s
# 905:	learn: 0.8217213	total: 9.64s	remaining: 1s
# 955:	learn: 0.8270492	total: 10.2s	remaining: 468ms
# 956:	learn: 0.8270492	total: 10.2s	remaining: 457ms
# 957:	learn: 0.8270492	total: 10.2s	remaining: 446ms
# 958:	learn: 0.8270492	total: 10.2s	remaining: 436ms
# 959:	learn: 0.8266393	total: 10.2s	remaining: 425ms
# 960:	learn: 0.8266393	total: 10.2s	remaining: 415ms
# 961:	learn: 0.8266393	total: 10.2s	remaining: 404ms
# 962:	learn: 0.8274590	total: 10.2s	remaining: 393ms
# 963:	learn: 0.8274590	total: 10.3s	remaining: 383ms
# 964:	learn: 0.8270492	total: 10.3s	remaining: 372ms
# 965:	learn: 0.8270492	total: 10.3s	remaining: 361ms
# 966:	learn: 0.8274590	total: 10.3s	remaining: 351ms
# 967:	learn: 0.8278689	total: 10.3s	remaining: 340ms
# 968:	learn: 0.8278689	total: 10.3s	remaining: 330ms
# 969:	learn: 0.8278689	total: 10.3s	remaining: 319ms
# 970:	learn: 0.8274590	total: 10.3s	remaining: 308ms
# 971:	learn: 0.8274590	total: 10.3s	remaining: 298ms
# 972:	learn: 0.8274590	total: 10.3s	remaining: 287ms
# 973:	learn: 0.8278689	total: 10.4s	remaining: 276ms
# 974:	learn: 0.8274590	total: 10.4s	remaining: 266ms
# 975:	learn: 0.8278689	total: 10.4s	remaining: 255ms
# 976:	learn: 0.8274590	total: 10.4s	remaining: 244ms
# 977:	learn: 0.8278689	total: 10.4s	remaining: 234ms
# 978:	learn: 0.8278689	total: 10.4s	remaining: 223ms
# 979:	learn: 0.8286885	total: 10.4s	remaining: 213ms
# 980:	learn: 0.8290984	total: 10.4s	remaining: 202ms
# 981:	learn: 0.8290984	total: 10.4s	remaining: 191ms
# 982:	learn: 0.8290984	total: 10.5s	remaining: 181ms
# 983:	learn: 0.8295082	total: 10.5s	remaining: 170ms
# 984:	learn: 0.8290984	total: 10.5s	remaining: 160ms
# 985:	learn: 0.8295082	total: 10.5s	remaining: 149ms
# 986:	learn: 0.8295082	total: 10.5s	remaining: 138ms
# 987:	learn: 0.8299180	total: 10.5s	remaining: 128ms
# 988:	learn: 0.8299180	total: 10.5s	remaining: 117ms
# 989:	learn: 0.8303279	total: 10.5s	remaining: 106ms
# 990:	learn: 0.8303279	total: 10.5s	remaining: 95.7ms
# 991:	learn: 0.8303279	total: 10.5s	remaining: 85ms
# 992:	learn: 0.8303279	total: 10.6s	remaining: 74.4ms
# 993:	learn: 0.8303279	total: 10.6s	remaining: 63.8ms
# 994:	learn: 0.8303279	total: 10.6s	remaining: 53.2ms
# 995:	learn: 0.8303279	total: 10.6s	remaining: 42.5ms
# 996:	learn: 0.8303279	total: 10.6s	remaining: 31.9ms
# 997:	learn: 0.8299180	total: 10.6s	remaining: 21.3ms
# 998:	learn: 0.8303279	total: 10.6s	remaining: 10.6ms
# 999:	learn: 0.8299180	total: 10.6s	remaining: 0us

# %%
all_sp_xgb_test_auc
# Out:
# [0.7548438369761313,
#  0.8951612903225807,
#  0.7616666666666666,
#  0.7321965500870391,
#  0.71565345206496]
